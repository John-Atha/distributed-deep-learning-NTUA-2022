# %%
# !pip install tensorflow-datasets==2.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.1 MB 37.9 MB/s
# ...
#   Attempting uninstall: tensorflow-datasets
#     Found existing installation: tensorflow-datasets 4.6.0
#     Uninstalling tensorflow-datasets-4.6.0:
#       Successfully uninstalled tensorflow-datasets-4.6.0
# ...

# %%
import tensorflow_datasets as tfds
# get DataSet
train_data = tfds.load(name="patch_camelyon", split="train",  data_dir="/tmp")
test_data = tfds.load(name="patch_camelyon", split="test",  data_dir="/tmp")

print(train_data)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# ...

# %%
# !ls /tmp/patch_camelyon/2.0.0
# Out:
# dataset_info.json
# image.image.json
# patch_camelyon-test.tfrecord-00000-of-00008
# patch_camelyon-test.tfrecord-00001-of-00008
# patch_camelyon-test.tfrecord-00002-of-00008
# patch_camelyon-test.tfrecord-00003-of-00008
# patch_camelyon-test.tfrecord-00004-of-00008
# patch_camelyon-test.tfrecord-00005-of-00008
# patch_camelyon-test.tfrecord-00006-of-00008
# patch_camelyon-test.tfrecord-00007-of-00008
# patch_camelyon-train.tfrecord-00000-of-00064
# patch_camelyon-train.tfrecord-00001-of-00064
# patch_camelyon-train.tfrecord-00002-of-00064
# patch_camelyon-train.tfrecord-00003-of-00064
# patch_camelyon-train.tfrecord-00004-of-00064
# patch_camelyon-train.tfrecord-00005-of-00064
# patch_camelyon-train.tfrecord-00006-of-00064
# patch_camelyon-train.tfrecord-00007-of-00064
# patch_camelyon-train.tfrecord-00008-of-00064
# patch_camelyon-train.tfrecord-00009-of-00064
# patch_camelyon-train.tfrecord-00010-of-00064
# patch_camelyon-train.tfrecord-00011-of-00064
# ...

# %%
from google.cloud import storage
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="sunny-mender-361506-78e64916a7f4.json"

# %%
storage_client = storage.Client()

buckets = list(storage_client.list_buckets())

bucket = storage_client.get_bucket("mybucket-bigdl-ece-ntua") # your bucket name

import os
path_of_the_directory= '/tmp/patch_camelyon/2.0.0'
print("Files and directories in a specified path:")
for filename in os.listdir(path_of_the_directory):
    f = os.path.join(path_of_the_directory,filename)
    if os.path.isfile(f):
        fname = f[26:]
        blob = bucket.blob('patch_camelyon/2.0.0/'+fname)
        blob.upload_from_filename("/tmp/patch_camelyon/2.0.0/"+fname)
        print(buckets)
# Out:
# Files and directories in a specified path:
# [<Bucket: dataproc-staging-us-central1-1002170547258-rqpjkl6n>, <Bucket: dataproc-temp-us-central1-1002170547258-lu4ms21b>, <Bucket: mybucket-bigdl-ece-ntua>]
# [<Bucket: dataproc-staging-us-central1-1002170547258-rqpjkl6n>, <Bucket: dataproc-temp-us-central1-1002170547258-lu4ms21b>, <Bucket: mybucket-bigdl-ece-ntua>]
# [<Bucket: dataproc-staging-us-central1-1002170547258-rqpjkl6n>, <Bucket: dataproc-temp-us-central1-1002170547258-lu4ms21b>, <Bucket: mybucket-bigdl-ece-ntua>]
# [<Bucket: dataproc-staging-us-central1-1002170547258-rqpjkl6n>, <Bucket: dataproc-temp-us-central1-1002170547258-lu4ms21b>, <Bucket: mybucket-bigdl-ece-ntua>]
# [<Bucket: dataproc-staging-us-central1-1002170547258-rqpjkl6n>, <Bucket: dataproc-temp-us-central1-1002170547258-lu4ms21b>, <Bucket: mybucket-bigdl-ece-ntua>]
# ...
